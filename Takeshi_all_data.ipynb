# %% [markdown]
# # Initial Data Observations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
departments = pd.read_csv("departments.csv")
diagnosis = pd.read_csv("diagnosis.csv")
encounters = pd.read_csv("encounters.csv")
patients = pd.read_csv("patients.csv")
providers = pd.read_csv("providers.csv")
social_determinants = pd.read_csv("social_determinants.csv")
tiger_census_codes = pd.read_csv("tigercensuscodes.csv")
# Out:
# /var/folders/5z/2qf3kgpn4s1268wng8ysvpl00000gq/T/ipykernel_3311/1600531716.py:6: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   social_determinants = pd.read_csv("social_determinants.csv")

# %%
departments
# Out:
#        DepartmentKey            Address             City           County  \
# 0                 -3           *Deleted         *Deleted         *Deleted
# 1                 -2    *Not Applicable  *Not Applicable  *Not Applicable
# 2                 -1       *Unspecified     *Unspecified     *Unspecified
# 3                  1    1500 SW 10th ST           TOPEKA     *Unspecified
# 4                  2     1979 Milky Way           VERONA     *Unspecified
# ...              ...                ...              ...              ...
# 11592          12908  909 SW Mulvane St           TOPEKA          SHAWNEE
# 11593          12909    1414 SW 8th Ave           Topeka     *Unspecified
# 11594          12910                NaN              NaN     *Unspecified
# 11595          12911   1500 SW 10th Ave           Topeka          SHAWNEE
# 11596          12912      330 SW Oakley           TOPEKA          SHAWNEE
#
#                        DepartmentName      DepartmentSpecialty  \
# 0                            *Deleted                 *Deleted
# 1                     *Not Applicable          *Not Applicable
# 2                        *Unspecified             *Unspecified
# 3                        INITIAL DEPT             *Unspecified
# 4                         EHS UM DEPT             *Unspecified
# ...                               ...                      ...
# 11592    STORMONT VAIL ALLERGY CLINIC                  Allergy
# 11593          CC HEMATOLOGY ONCOLOGY  Hematology and Oncology
# 11594                    *Unspecified             *Unspecified
# 11595              SV PHARMACOTHERAPY                 Pharmacy
# 11596  ASTRA MENTAL HEALTH & RECOVERY          *Not Applicable
#
#         DepartmentType       PostalCode   CensusTract
# 0             *Deleted         *Deleted           NaN
# 1      *Not Applicable  *Not Applicable           NaN
# 2         *Unspecified     *Unspecified           NaN
# 3             *Unknown            66604  2.017700e+10
# 4             *Unknown            53593  5.502501e+10
# ...                ...              ...           ...
# 11592         *Unknown            66606  2.017700e+10
# 11593         *Unknown            66606  2.017700e+10
# 11594     *Unspecified              NaN           NaN
# 11595              HOD            66606  2.017700e+10
# 11596  *Not Applicable            66606  2.017700e+10
#
# [11597 rows x 9 columns]

# %%
diagnosis
# Out:
#          DiagnosisKey                                          GroupName  \
# 0                 2.0                     Typhoid and paratyphoid fevers
# 1                 3.0                           Respiratory tuberculosis
# 2                 7.0                   Fracture at wrist and hand level
# 3                 8.0                                    Fracture of rib
# 4                 9.0                   Fracture at wrist and hand level
# ...               ...                                                ...
# 1531257     1629328.0  Reserved for inherently not codable concepts w...
# 1531258     1629331.0  Reserved for concepts with insufficient inform...
# 1531259     1629340.0  Reserved for concepts with insufficient inform...
# 1531260     1629341.0  Reserved for concepts with insufficient inform...
# 1531261     1629359.0                          Abdominal and pelvic pain
#
#                   GroupCode  \
# 0            ICD-10-CM: A01
# 1            ICD-10-CM: A15
# 2            ICD-10-CM: S62
# 3            ICD-10-CM: S22
# 4            ICD-10-CM: S62
# ...                     ...
# 1531257  ICD-10-CM: IMO0001
# 1531258  ICD-10-CM: IMO0002
# 1531259  ICD-10-CM: IMO0002
# 1531260  ICD-10-CM: IMO0002
# 1531261      ICD-10-CM: R10
#
#                                              DiagnosisName DiagnosisValue
# 0        Paratyphoid fever, unspecified( ICD-10-CM: A01...          A01.4
# 1        Primary respiratory tuberculosis( ICD-10-CM: A...          A15.7
# 2        Displaced fracture of pisiform, unspecified wr...       S62.163K
# 3        Multiple fractures of ribs, right side, subseq...       S22.41XG
# 4        Nondisplaced fracture of distal phalanx of lef...       S62.663G
# ...                                                    ...            ...
# 1531257  Reserved for inherently not codable concepts w...        IMO0001
# 1531258  Reserved for concepts with insufficient inform...        IMO0002
# 1531259  Reserved for concepts with insufficient inform...        IMO0002
# 1531260  Reserved for concepts with insufficient inform...        IMO0002
# 1531261  Pelvic and perineal pain bilateral( ICD-10-CM:...         R10.23
#
# [1531262 rows x 5 columns]

# %%
encounters
# Out:
#              Date     AdmissionInstant  AdmitYear  AdmitMonth  AdmitDay  \
# 0        04/25/22  2022-04-25 20:33:00     2022.0         4.0      25.0
# 1        04/29/22  2022-04-29 18:18:00     2022.0         4.0      29.0
# 2        01/10/22  2022-01-10 05:52:00     2022.0         1.0      10.0
# 3        03/08/22  2022-03-08 09:08:00     2022.0         3.0       8.0
# 4        03/16/22  2022-03-16 14:19:00     2022.0         3.0      16.0
# ...           ...                  ...        ...         ...       ...
# 7675796  12/29/25                  NaN        NaN         NaN       NaN
# 7675797  12/12/25                  NaN        NaN         NaN       NaN
# 7675798  12/12/25                  NaN        NaN         NaN       NaN
# 7675799  08/20/25                  NaN        NaN         NaN       NaN
# 7675800  07/17/25                  NaN        NaN         NaN       NaN
#
#          AdmitHour  AdmitMinute                           AdmissionSource  \
# 0             20.0         33.0  Non-Health Care Facility Point of Origin
# 1             18.0         18.0                 Clinic/Physician Referral
# 2              5.0         52.0  Non-Health Care Facility Point of Origin
# 3              9.0          8.0  Non-Health Care Facility Point of Origin
# 4             14.0         19.0  Non-Health Care Facility Point of Origin
# ...            ...          ...                                       ...
# 7675796        NaN          NaN                           *Not Applicable
# 7675797        NaN          NaN                           *Not Applicable
# 7675798        NaN          NaN                           *Not Applicable
# 7675799        NaN          NaN                           *Not Applicable
# 7675800        NaN          NaN                           *Not Applicable
#
#            AdmissionType     DischargeInstant  ...  \
# 0               Elective  2022-04-25 21:35:00  ...
# 1               Elective  2022-04-29 18:20:00  ...
# 2               Elective  2022-01-12 11:43:00  ...
# 3               Elective  2022-03-10 13:45:00  ...
# 4               Elective  2022-03-16 16:00:00  ...
# ...                  ...                  ...  ...
# 7675796  *Not Applicable                  NaN  ...
# 7675797  *Not Applicable                  NaN  ...
# 7675798  *Not Applicable                  NaN  ...
# 7675799  *Not Applicable                  NaN  ...
# 7675800  *Not Applicable                  NaN  ...
#
#          AttendingProviderDurableKey  DischargeProviderDurableKey  \
# 0                               2982                         2982
# 1                               2979                         2979
# 2                               6223                         7015
# 3                               7973                         7973
# 4                               6223                         2982
# ...                              ...                          ...
# 7675796                        18326                           -1
# 7675797                           -1                           -1
# 7675798                        79382                           -1
# 7675799                         1868                           -1
# 7675800                         1868                           -1
#
#          DepartmentKey  PrimaryDiagnosisKey  IsEdVisit  IsHospitalAdmission  \
# 0                   27               910699          0                    1
# 1                   27                   -1          0                    1
# 2                   27               468738          0                    1
# 3                   27               468492          0                    1
# 4                   27               907210          0                    1
# ...                ...                  ...        ...                  ...
# 7675796             57               858635          0                    0
# 7675797          12707                   -1          0                    0
# 7675798             57               855970          0                    0
# 7675799          11805               853446          0                    0
# 7675800          11805               853446          0                    0
#
#          IsHospitalOutpatientVisit IsInpatientAdmission IsObservation  \
# 0                                0                    0             1
# 1                                0                    0             1
# 2                                0                    1             0
# 3                                0                    1             0
# 4                                0                    0             1
# ...                            ...                  ...           ...
# 7675796                          0                    0             0
# 7675797                          0                    0             0
# 7675798                          0                    0             0
# 7675799                          0                    0             0
# 7675800                          0                    0             0
#
#         IsOutpatientFaceToFaceVisit
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...
# 7675796                           1
# 7675797                           1
# 7675798                           1
# 7675799                           0
# 7675800                           0
#
# [7675801 rows x 31 columns]

# %%
encounters.isnull().sum()
# Out:
# Date                                 0
# AdmissionInstant               6627001
# AdmitYear                      6627001
# AdmitMonth                     6627001
# AdmitDay                       6627001
# AdmitHour                      6627001
# AdmitMinute                    6627001
# AdmissionSource                   1400
# AdmissionType                     1086
# DischargeInstant               6627001
# DischargeYear                  6627001
# DischargeMonth                 6627001
# DischargeDay                   6627001
# DischargeHour                  6627001
# DischargeMinute                6627001
# EncounterKey                         0
# PatientDurableKey                    0
# Type                                 0
# VisitType                            0
# VisitTypeDescription                 0
# ProviderDurableKey                   0
# AttendingProviderDurableKey          0
# DischargeProviderDurableKey          0
# DepartmentKey                        0
# PrimaryDiagnosisKey                  0
# IsEdVisit                            0
# IsHospitalAdmission                  0
# IsHospitalOutpatientVisit            0
# IsInpatientAdmission                 0
# IsObservation                        0
# IsOutpatientFaceToFaceVisit          0
# dtype: int64

# %%
1531262/7675801
# Out:
# 0.19949214420749053

# %%
encounters_null = encounters.loc[encounters["DischargeYear"].isnull()]
encounters_null
# Out:
#              Date AdmissionInstant  AdmitYear  AdmitMonth  AdmitDay  \
# 8        01/03/22              NaN        NaN         NaN       NaN
# 9        01/31/22              NaN        NaN         NaN       NaN
# 10       01/31/22              NaN        NaN         NaN       NaN
# 11       01/24/22              NaN        NaN         NaN       NaN
# 12       01/26/22              NaN        NaN         NaN       NaN
# ...           ...              ...        ...         ...       ...
# 7675796  12/29/25              NaN        NaN         NaN       NaN
# 7675797  12/12/25              NaN        NaN         NaN       NaN
# 7675798  12/12/25              NaN        NaN         NaN       NaN
# 7675799  08/20/25              NaN        NaN         NaN       NaN
# 7675800  07/17/25              NaN        NaN         NaN       NaN
#
#          AdmitHour  AdmitMinute  AdmissionSource    AdmissionType  \
# 8              NaN          NaN  *Not Applicable  *Not Applicable
# 9              NaN          NaN  *Not Applicable  *Not Applicable
# 10             NaN          NaN  *Not Applicable  *Not Applicable
# 11             NaN          NaN  *Not Applicable  *Not Applicable
# 12             NaN          NaN  *Not Applicable  *Not Applicable
# ...            ...          ...              ...              ...
# 7675796        NaN          NaN  *Not Applicable  *Not Applicable
# 7675797        NaN          NaN  *Not Applicable  *Not Applicable
# 7675798        NaN          NaN  *Not Applicable  *Not Applicable
# 7675799        NaN          NaN  *Not Applicable  *Not Applicable
# 7675800        NaN          NaN  *Not Applicable  *Not Applicable
#
#         DischargeInstant  ...  AttendingProviderDurableKey  \
# 8                    NaN  ...                           -1
# 9                    NaN  ...                           -1
# 10                   NaN  ...                           -1
# 11                   NaN  ...                           -1
# 12                   NaN  ...                           -1
# ...                  ...  ...                          ...
# 7675796              NaN  ...                        18326
# 7675797              NaN  ...                           -1
# 7675798              NaN  ...                        79382
# 7675799              NaN  ...                         1868
# 7675800              NaN  ...                         1868
#
#          DischargeProviderDurableKey  DepartmentKey  PrimaryDiagnosisKey  \
# 8                                 -1          10279               793876
# 9                                 -1          10279               694326
# 10                                -1          10279               686369
# 11                                -1            349               847384
# 12                                -1          10279              1016440
# ...                              ...            ...                  ...
# 7675796                           -1             57               858635
# 7675797                           -1          12707                   -1
# 7675798                           -1             57               855970
# 7675799                           -1          11805               853446
# 7675800                           -1          11805               853446
#
#          IsEdVisit  IsHospitalAdmission  IsHospitalOutpatientVisit  \
# 8                0                    0                          0
# 9                0                    0                          0
# 10               0                    0                          0
# 11               0                    0                          0
# 12               0                    0                          0
# ...            ...                  ...                        ...
# 7675796          0                    0                          0
# 7675797          0                    0                          0
# 7675798          0                    0                          0
# 7675799          0                    0                          0
# 7675800          0                    0                          0
#
#         IsInpatientAdmission IsObservation IsOutpatientFaceToFaceVisit
# 8                          0             0                           1
# 9                          0             0                           1
# 10                         0             0                           1
# 11                         0             0                           1
# 12                         0             0                           1
# ...                      ...           ...                         ...
# 7675796                    0             0                           1
# 7675797                    0             0                           1
# 7675798                    0             0                           1
# 7675799                    0             0                           0
# 7675800                    0             0                           0
#
# [6627001 rows x 31 columns]

# %%
encounters_null.isnull().sum()
# Out:
# Date                                 0
# AdmissionInstant               6627001
# AdmitYear                      6627001
# AdmitMonth                     6627001
# AdmitDay                       6627001
# AdmitHour                      6627001
# AdmitMinute                    6627001
# AdmissionSource                      1
# AdmissionType                        1
# DischargeInstant               6627001
# DischargeYear                  6627001
# DischargeMonth                 6627001
# DischargeDay                   6627001
# DischargeHour                  6627001
# DischargeMinute                6627001
# EncounterKey                         0
# PatientDurableKey                    0
# Type                                 0
# VisitType                            0
# VisitTypeDescription                 0
# ProviderDurableKey                   0
# AttendingProviderDurableKey          0
# DischargeProviderDurableKey          0
# DepartmentKey                        0
# PrimaryDiagnosisKey                  0
# IsEdVisit                            0
# IsHospitalAdmission                  0
# IsHospitalOutpatientVisit            0
# IsInpatientAdmission                 0
# IsObservation                        0
# IsOutpatientFaceToFaceVisit          0
# dtype: int64

# %%
encounters_null["VisitType"].value_counts()
# Out:
# VisitType
# LAB                                 1114143
# FOLLOW UP                            980175
# *Unspecified                         848133
# X-RAY VT                             346126
# OFFICE VISIT                         291575
#                                      ...
# EGD/FLEX SIG-MSH                          1
# OAKLAND COMM CTR HOSP/FU                  1
# MRI ANGIO ABDOMEN WO CONTRAST VT          1
# ENDO/IUD                                  1
# US FHC OB/GYN ULTRASOUND VT               1
# Name: count, Length: 1073, dtype: int64

# %%
encounters_not_null = encounters.loc[~encounters["DischargeYear"].isnull()]
encounters_not_null
# Out:
#              Date     AdmissionInstant  AdmitYear  AdmitMonth  AdmitDay  \
# 0        04/25/22  2022-04-25 20:33:00     2022.0         4.0      25.0
# 1        04/29/22  2022-04-29 18:18:00     2022.0         4.0      29.0
# 2        01/10/22  2022-01-10 05:52:00     2022.0         1.0      10.0
# 3        03/08/22  2022-03-08 09:08:00     2022.0         3.0       8.0
# 4        03/16/22  2022-03-16 14:19:00     2022.0         3.0      16.0
# ...           ...                  ...        ...         ...       ...
# 7674805  12/31/25  2025-12-31 22:16:00     2025.0        12.0      31.0
# 7674834  12/31/25  2025-12-31 19:31:00     2025.0        12.0      31.0
# 7674847  12/31/25  2025-12-31 15:56:00     2025.0        12.0      31.0
# 7674886  12/31/25  2025-12-31 10:49:00     2025.0        12.0      31.0
# 7675288  12/31/25  2025-12-31 23:59:00     2025.0        12.0      31.0
#
#          AdmitHour  AdmitMinute                           AdmissionSource  \
# 0             20.0         33.0  Non-Health Care Facility Point of Origin
# 1             18.0         18.0                 Clinic/Physician Referral
# 2              5.0         52.0  Non-Health Care Facility Point of Origin
# 3              9.0          8.0  Non-Health Care Facility Point of Origin
# 4             14.0         19.0  Non-Health Care Facility Point of Origin
# ...            ...          ...                                       ...
# 7674805       22.0         16.0  Non-Health Care Facility Point of Origin
# 7674834       19.0         31.0  Non-Health Care Facility Point of Origin
# 7674847       15.0         56.0  Non-Health Care Facility Point of Origin
# 7674886       10.0         49.0  Non-Health Care Facility Point of Origin
# 7675288       23.0         59.0                 Clinic/Physician Referral
#
#         AdmissionType     DischargeInstant  ...  AttendingProviderDurableKey  \
# 0            Elective  2022-04-25 21:35:00  ...                         2982
# 1            Elective  2022-04-29 18:20:00  ...                         2979
# 2            Elective  2022-01-12 11:43:00  ...                         6223
# 3            Elective  2022-03-10 13:45:00  ...                         7973
# 4            Elective  2022-03-16 16:00:00  ...                         6223
# ...               ...                  ...  ...                          ...
# 7674805     Emergency  2025-12-31 22:27:00  ...                        73372
# 7674834     Emergency  2025-12-31 19:36:00  ...                         6561
# 7674847     Emergency  2025-12-31 15:57:00  ...                        26866
# 7674886     Emergency  2025-12-31 10:50:00  ...                         6561
# 7675288      Elective  2025-12-31 23:59:00  ...                         1238
#
#          DischargeProviderDurableKey  DepartmentKey  PrimaryDiagnosisKey  \
# 0                               2982             27               910699
# 1                               2979             27                   -1
# 2                               7015             27               468738
# 3                               7973             27               468492
# 4                               2982             27               907210
# ...                              ...            ...                  ...
# 7674805                        73372          11788               865125
# 7674834                           -1             20               855088
# 7674847                        26866             20               864701
# 7674886                           -1             20               915009
# 7675288                           -1             44                   -1
#
#          IsEdVisit  IsHospitalAdmission  IsHospitalOutpatientVisit  \
# 0                0                    1                          0
# 1                0                    1                          0
# 2                0                    1                          0
# 3                0                    1                          0
# 4                0                    1                          0
# ...            ...                  ...                        ...
# 7674805          1                    0                          0
# 7674834          1                    0                          0
# 7674847          1                    0                          0
# 7674886          1                    0                          0
# 7675288          0                    0                          1
#
#         IsInpatientAdmission IsObservation IsOutpatientFaceToFaceVisit
# 0                          0             1                           0
# 1                          0             1                           0
# 2                          1             0                           0
# 3                          1             0                           0
# 4                          0             1                           0
# ...                      ...           ...                         ...
# 7674805                    0             0                           0
# 7674834                    0             0                           0
# 7674847                    0             0                           0
# 7674886                    0             0                           0
# 7675288                    0             0                           1
#
# [1048800 rows x 31 columns]

# %%
encounters_not_null["VisitType"].value_counts()
# Out:
# VisitType
# *Unspecified                              365693
# RXT10                                      42205
# CR PHASE 2                                 34002
# FL FLUORO GUIDE SPINAL PUNCTURE OP VT      28820
# ECHOCARDIOGRAM ADULT                       27493
#                                            ...
# CT LUMBAR SPINE W CONTRAST AFTER NM VT         1
# MRI NEUROGRAPHY VT ANESTHESIA VT               1
# CT CHEST W WO CONTRAST HVT                     1
# US DUPLEX ABDOMEN VASCULAR LIMITED VT          1
# LEQVIO INJECTION                               1
# Name: count, Length: 1056, dtype: int64

# %%
encounters_null["Type"].value_counts()
# Out:
# Type
# Office Visit                2249136
# Lab Visit                   1052018
# Appointment                  778962
# Patient Outreach             555223
# Imaging                      526382
# Treatment                    325547
# Lab Requisition              202048
# Follow-Up                    156964
# Initial consult              142248
# Procedure visit              130701
# Telemedicine                 117123
# Well Child                   110177
# Surgery                       72851
# Anti-coag visit               66814
# Routine Prenatal              63820
# Infusion                      55337
# Pre-Endoscopy Assessment      21650
# Name: count, dtype: int64

# %%
encounters_not_null["Type"].value_counts()
# Out:
# Type
# Hospital Encounter    1048800
# Name: count, dtype: int64

# %%
departments["Address"].value_counts()
# Out:
# Address
# 1500 SW 10th Ave                  3254
# 1979 Milky Way                    1552
# *Unknown                          1383
# 1102 St Marys Rd                   477
# 1414 SW 8th Ave                    222
#                                   ...
# 2921 SW Wanamaker Dr                 1
# 3620 SW Fairlawn Rd. Suite 100       1
# 3107 W 21st St                       1
# 1315 SW 6th St, Ste A                1
# 330 SW Oakley                        1
# Name: count, Length: 467, dtype: int64

# %%
diagnosis
# Out:
#          DiagnosisKey                                          GroupName  \
# 0                 2.0                     Typhoid and paratyphoid fevers
# 1                 3.0                           Respiratory tuberculosis
# 2                 7.0                   Fracture at wrist and hand level
# 3                 8.0                                    Fracture of rib
# 4                 9.0                   Fracture at wrist and hand level
# ...               ...                                                ...
# 1531257     1629328.0  Reserved for inherently not codable concepts w...
# 1531258     1629331.0  Reserved for concepts with insufficient inform...
# 1531259     1629340.0  Reserved for concepts with insufficient inform...
# 1531260     1629341.0  Reserved for concepts with insufficient inform...
# 1531261     1629359.0                          Abdominal and pelvic pain
#
#                   GroupCode  \
# 0            ICD-10-CM: A01
# 1            ICD-10-CM: A15
# 2            ICD-10-CM: S62
# 3            ICD-10-CM: S22
# 4            ICD-10-CM: S62
# ...                     ...
# 1531257  ICD-10-CM: IMO0001
# 1531258  ICD-10-CM: IMO0002
# 1531259  ICD-10-CM: IMO0002
# 1531260  ICD-10-CM: IMO0002
# 1531261      ICD-10-CM: R10
#
#                                              DiagnosisName DiagnosisValue
# 0        Paratyphoid fever, unspecified( ICD-10-CM: A01...          A01.4
# 1        Primary respiratory tuberculosis( ICD-10-CM: A...          A15.7
# 2        Displaced fracture of pisiform, unspecified wr...       S62.163K
# 3        Multiple fractures of ribs, right side, subseq...       S22.41XG
# 4        Nondisplaced fracture of distal phalanx of lef...       S62.663G
# ...                                                    ...            ...
# 1531257  Reserved for inherently not codable concepts w...        IMO0001
# 1531258  Reserved for concepts with insufficient inform...        IMO0002
# 1531259  Reserved for concepts with insufficient inform...        IMO0002
# 1531260  Reserved for concepts with insufficient inform...        IMO0002
# 1531261  Pelvic and perineal pain bilateral( ICD-10-CM:...         R10.23
#
# [1531262 rows x 5 columns]

# %%
encounters_null.loc[encounters_null["VisitType"] == "*Unspecified"]["Type"].value_counts()
# Out:
# Type
# Patient Outreach            530810
# Lab Requisition             202048
# Surgery                      72851
# Pre-Endoscopy Assessment     21650
# Office Visit                  8546
# Anti-coag visit               7892
# Treatment                     4200
# Routine Prenatal               134
# Telemedicine                     1
# Appointment                      1
# Name: count, dtype: int64

# %%
encounters.loc[encounters["IsEdVisit"] == 1]["VisitType"].value_counts()
# Out:
# VisitType
# *Unspecified                                               261457
# CT GUIDED AND MONITORING PARENCHYMAL TISSUE ABLATION VT         1
# Name: count, dtype: int64

# %%
encounters_null.loc[encounters["IsEdVisit"] == 1]["VisitType"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
patients
# Out:
#        CensusBlockGroupFipsCode  DurableKey                     FirstRace  \
# 0                  201770007002         5.0            White or Caucasian
# 1                  *Unspecified         8.0            White or Caucasian
# 2                  *Unspecified         9.0  Hispanic, Latino, or Spanish
# 3                  *Unspecified        11.0  Hispanic, Latino, or Spanish
# 4                  *Unspecified        12.0     Black or African American
# ...                         ...         ...                           ...
# 947680             *Unspecified  11135768.0                           NaN
# 947681             *Unspecified  11135771.0                           NaN
# 947682             *Unspecified  11135772.0                           NaN
# 947683             *Unspecified  11135773.0                           NaN
# 947684             201110003001  11135791.0            White or Caucasian
#
#        MaritalStatus MyChartStatus            OmbEthnicity  \
# 0             Single     Activated  Not Hispanic or Latino
# 1       *Unspecified   Inactivated                 Unknown
# 2            Married  *Unspecified                 Unknown
# 3            Unknown  *Unspecified      Hispanic or Latino
# 4             Single  *Unspecified  Not Hispanic or Latino
# ...              ...           ...                     ...
# 947680  *Unspecified  *Unspecified                 Unknown
# 947681  *Unspecified  *Unspecified                 Unknown
# 947682  *Unspecified   Inactivated                 Unknown
# 947683  *Unspecified  *Unspecified                 Unknown
# 947684       Married     Activated  Not Hispanic or Latino
#
#                           OmbRace SexAssignedAtBirth SexualOrientation  \
# 0                           White       *Unspecified      *Unspecified
# 1                           White       *Unspecified      *Unspecified
# 2                 Some Other Race       *Unspecified      *Unspecified
# 3                 Some Other Race       *Unspecified      *Unspecified
# 4       Black or African American       *Unspecified      *Unspecified
# ...                           ...                ...               ...
# 947680                    Unknown       *Unspecified      *Unspecified
# 947681                    Unknown       *Unspecified      *Unspecified
# 947682                    Unknown       *Unspecified      *Unspecified
# 947683                    Unknown       *Unspecified      *Unspecified
# 947684                      White       *Unspecified      *Unspecified
#
#        SmokingStatus VitalStatus  PatientBirthYearBin
# 0              Never       Alive               1970.0
# 1           *Unknown       Alive               1980.0
# 2              Never       Alive               1955.0
# 3              Never       Alive               1970.0
# 4              Never       Alive               1980.0
# ...              ...         ...                  ...
# 947680      *Unknown       Alive                  NaN
# 947681      *Unknown       Alive                  NaN
# 947682      *Unknown       Alive               2005.0
# 947683      *Unknown       Alive                  NaN
# 947684         Never       Alive               1960.0
#
# [947685 rows x 12 columns]

# %%
diagnosis["GroupName"].value_counts()
# Out:
# GroupName
# Fracture of lower leg, including ankle                              84079
# Fracture of forearm                                                 68275
# Fracture at wrist and hand level                                    58559
# Fracture of femur                                                   57718
# Intracranial injury                                                 50269
#                                                                     ...
# Accidental exposure to other specified factors                          1
# Encounter for delivery                                                  1
# -X69 deactivated.  See categories T36-T65 with sixth-character 2        1
# Deactivated.  See T81.5                                                 1
# Events resulting in loss of self-esteem in childhood                    1
# Name: count, Length: 1991, dtype: int64

# %%
encounters_null
# Out:
#              Date AdmissionInstant  AdmitYear  AdmitMonth  AdmitDay  \
# 8        01/03/22              NaN        NaN         NaN       NaN
# 9        01/31/22              NaN        NaN         NaN       NaN
# 10       01/31/22              NaN        NaN         NaN       NaN
# 11       01/24/22              NaN        NaN         NaN       NaN
# 12       01/26/22              NaN        NaN         NaN       NaN
# ...           ...              ...        ...         ...       ...
# 7675796  12/29/25              NaN        NaN         NaN       NaN
# 7675797  12/12/25              NaN        NaN         NaN       NaN
# 7675798  12/12/25              NaN        NaN         NaN       NaN
# 7675799  08/20/25              NaN        NaN         NaN       NaN
# 7675800  07/17/25              NaN        NaN         NaN       NaN
#
#          AdmitHour  AdmitMinute  AdmissionSource    AdmissionType  \
# 8              NaN          NaN  *Not Applicable  *Not Applicable
# 9              NaN          NaN  *Not Applicable  *Not Applicable
# 10             NaN          NaN  *Not Applicable  *Not Applicable
# 11             NaN          NaN  *Not Applicable  *Not Applicable
# 12             NaN          NaN  *Not Applicable  *Not Applicable
# ...            ...          ...              ...              ...
# 7675796        NaN          NaN  *Not Applicable  *Not Applicable
# 7675797        NaN          NaN  *Not Applicable  *Not Applicable
# 7675798        NaN          NaN  *Not Applicable  *Not Applicable
# 7675799        NaN          NaN  *Not Applicable  *Not Applicable
# 7675800        NaN          NaN  *Not Applicable  *Not Applicable
#
#         DischargeInstant  ...  AttendingProviderDurableKey  \
# 8                    NaN  ...                           -1
# 9                    NaN  ...                           -1
# 10                   NaN  ...                           -1
# 11                   NaN  ...                           -1
# 12                   NaN  ...                           -1
# ...                  ...  ...                          ...
# 7675796              NaN  ...                        18326
# 7675797              NaN  ...                           -1
# 7675798              NaN  ...                        79382
# 7675799              NaN  ...                         1868
# 7675800              NaN  ...                         1868
#
#          DischargeProviderDurableKey  DepartmentKey  PrimaryDiagnosisKey  \
# 8                                 -1          10279               793876
# 9                                 -1          10279               694326
# 10                                -1          10279               686369
# 11                                -1            349               847384
# 12                                -1          10279              1016440
# ...                              ...            ...                  ...
# 7675796                           -1             57               858635
# 7675797                           -1          12707                   -1
# 7675798                           -1             57               855970
# 7675799                           -1          11805               853446
# 7675800                           -1          11805               853446
#
#          IsEdVisit  IsHospitalAdmission  IsHospitalOutpatientVisit  \
# 8                0                    0                          0
# 9                0                    0                          0
# 10               0                    0                          0
# 11               0                    0                          0
# 12               0                    0                          0
# ...            ...                  ...                        ...
# 7675796          0                    0                          0
# 7675797          0                    0                          0
# 7675798          0                    0                          0
# 7675799          0                    0                          0
# 7675800          0                    0                          0
#
#         IsInpatientAdmission IsObservation IsOutpatientFaceToFaceVisit
# 8                          0             0                           1
# 9                          0             0                           1
# 10                         0             0                           1
# 11                         0             0                           1
# 12                         0             0                           1
# ...                      ...           ...                         ...
# 7675796                    0             0                           1
# 7675797                    0             0                           1
# 7675798                    0             0                           1
# 7675799                    0             0                           0
# 7675800                    0             0                           0
#
# [6627001 rows x 31 columns]

# %%
diagnosis.loc[diagnosis["GroupName"] == "Sleep disorders"]
# Out:
#          DiagnosisKey        GroupName       GroupCode  \
# 19044         18232.0  Sleep disorders  ICD-10-CM: G47
# 25669         24480.0  Sleep disorders  ICD-10-CM: G47
# 25693         24503.0  Sleep disorders  ICD-10-CM: G47
# 25694         24504.0  Sleep disorders  ICD-10-CM: G47
# 25973         24792.0  Sleep disorders  ICD-10-CM: G47
# ...               ...              ...             ...
# 1527895     1626044.0  Sleep disorders  ICD-10-CM: G47
# 1528149     1626249.0  Sleep disorders  ICD-10-CM: G47
# 1530466     1628089.0  Sleep disorders  ICD-10-CM: G47
# 1530514     1628127.0  Sleep disorders  ICD-10-CM: G47
# 1530787     1628328.0  Sleep disorders  ICD-10-CM: G47
#
#                                              DiagnosisName DiagnosisValue
# 19044        Sleep apnea, unspecified( ICD-10-CM: G47.30 )         G47.30
# 25669    Circadian rhythm sleep disorder, irregular sle...         G47.23
# 25693    Circadian rhythm sleep disorder, shift work ty...         G47.26
# 25694    Circadian rhythm sleep disorder, shift work ty...         G47.26
# 25973        Hypersomnia, unspecified( ICD-10-CM: G47.10 )         G47.10
# ...                                                    ...            ...
# 1527895    Sleep disorder, unspecified( ICD-10-CM: G47.9 )          G47.9
# 1528149   Primary central sleep apnea( ICD-10-CM: G47.31 )         G47.31
# 1530466              Other parasomnia( ICD-10-CM: G47.59 )         G47.59
# 1530514  Circadian rhythm sleep disorder, advanced slee...         G47.22
# 1530787    Sleep disorder, unspecified( ICD-10-CM: G47.9 )          G47.9
#
# [851 rows x 5 columns]

# %%
df = pd.merge(encounters, diagnosis, left_on = "PrimaryDiagnosisKey", right_on = "DiagnosisKey")
df["Depressives"] = df["GroupName"].str.contains("Depressive", case = False, na = False).astype(int)
depressives_df = df.loc[df["Depressives"] == 1]
depressives_df["Date"] = pd.to_datetime(depressives_df["Date"], format = "mixed")
# Out:
# /var/folders/5z/2qf3kgpn4s1268wng8ysvpl00000gq/T/ipykernel_1557/3994361288.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   depressives_df["Date"] = pd.to_datetime(depressives_df["Date"], format = "mixed")

# %%
depressives_df
# Out:
#               Date     AdmissionInstant  AdmitYear  AdmitMonth  AdmitDay  \
# 232     2022-01-31                  NaN        NaN         NaN       NaN
# 272     2022-02-09                  NaN        NaN         NaN       NaN
# 329     2022-01-04                  NaN        NaN         NaN       NaN
# 2120    2022-01-19                  NaN        NaN         NaN       NaN
# 2481    2022-01-10                  NaN        NaN         NaN       NaN
# ...            ...                  ...        ...         ...       ...
# 6517653 2025-12-31  2025-12-31 12:20:00     2025.0        12.0      31.0
# 6517681 2025-12-31  2025-12-31 21:56:00     2025.0        12.0      31.0
# 6518140 2025-12-31  2025-12-31 00:26:00     2025.0        12.0      31.0
# 6518967 2025-12-31                  NaN        NaN         NaN       NaN
# 6519145 2025-12-31                  NaN        NaN         NaN       NaN
#
#          AdmitHour  AdmitMinute  \
# 232            NaN          NaN
# 272            NaN          NaN
# 329            NaN          NaN
# 2120           NaN          NaN
# 2481           NaN          NaN
# ...            ...          ...
# 6517653       12.0         20.0
# 6517681       21.0         56.0
# 6518140        0.0         26.0
# 6518967        NaN          NaN
# 6519145        NaN          NaN
#
#                                        AdmissionSource    AdmissionType  \
# 232                                    *Not Applicable  *Not Applicable
# 272                                    *Not Applicable  *Not Applicable
# 329                                    *Not Applicable  *Not Applicable
# 2120                                   *Not Applicable  *Not Applicable
# 2481                                   *Not Applicable  *Not Applicable
# ...                                                ...              ...
# 6517653  Transfer from a Hospital (Different Facility)           Urgent
# 6517681     Transfer from Another Health Care Facility           Urgent
# 6518140       Non-Health Care Facility Point of Origin        Emergency
# 6518967                                *Not Applicable  *Not Applicable
# 6519145                                *Not Applicable  *Not Applicable
#
#             DischargeInstant  ...  IsHospitalOutpatientVisit  \
# 232                      NaN  ...                          0
# 272                      NaN  ...                          0
# 329                      NaN  ...                          0
# 2120                     NaN  ...                          0
# 2481                     NaN  ...                          0
# ...                      ...  ...                        ...
# 6517653  2026-01-06 17:29:00  ...                          0
# 6517681  2026-01-03 11:53:00  ...                          0
# 6518140  2025-12-31 08:59:00  ...                          0
# 6518967                  NaN  ...                          0
# 6519145                  NaN  ...                          0
#
#          IsInpatientAdmission  IsObservation  IsOutpatientFaceToFaceVisit  \
# 232                         0              0                            1
# 272                         0              0                            1
# 329                         0              0                            1
# 2120                        0              0                            1
# 2481                        0              0                            1
# ...                       ...            ...                          ...
# 6517653                     1              0                            0
# 6517681                     1              0                            0
# 6518140                     0              0                            0
# 6518967                     0              0                            0
# 6519145                     0              0                            0
#
#          DiagnosisKey                                  GroupName  \
# 232          407627.0       Major depressive disorder, recurrent
# 272          605675.0  Major depressive disorder, single episode
# 329          698235.0  Major depressive disorder, single episode
# 2120         407627.0       Major depressive disorder, recurrent
# 2481         407639.0       Major depressive disorder, recurrent
# ...               ...                                        ...
# 6517653      906402.0       Major depressive disorder, recurrent
# 6517681      906402.0       Major depressive disorder, recurrent
# 6518140      854596.0  Major depressive disorder, single episode
# 6518967      407639.0       Major depressive disorder, recurrent
# 6519145      663628.0       Major depressive disorder, recurrent
#
#               GroupCode                                      DiagnosisName  \
# 232      ICD-10-CM: F33  Major depressive disorder, recurrent, mild( IC...
# 272      ICD-10-CM: F32        Depression, unspecified( ICD-10-CM: F32.A )
# 329      ICD-10-CM: F32  Other specified depressive episodes( ICD-10-CM...
# 2120     ICD-10-CM: F33  Major depressive disorder, recurrent, mild( IC...
# 2481     ICD-10-CM: F33  Major depressive disorder, recurrent, in parti...
# ...                 ...                                                ...
# 6517653  ICD-10-CM: F33  Major depressive disorder, recurrent severe wi...
# 6517681  ICD-10-CM: F33  Major depressive disorder, recurrent severe wi...
# 6518140  ICD-10-CM: F32  Major depressive disorder, single episode, uns...
# 6518967  ICD-10-CM: F33  Major depressive disorder, recurrent, in parti...
# 6519145  ICD-10-CM: F33  Major depressive disorder, recurrent, moderate...
#
#         DiagnosisValue Depressives
# 232              F33.0           1
# 272              F32.A           1
# 329             F32.89           1
# 2120             F33.0           1
# 2481            F33.41           1
# ...                ...         ...
# 6517653          F33.2           1
# 6517681          F33.2           1
# 6518140          F32.9           1
# 6518967         F33.41           1
# 6519145          F33.1           1
#
# [27490 rows x 37 columns]

# %%
# df should be a sub-dataframe of encounters with all encounters involving the relevant diagnoses
# in your input df, make sure you change the "Date" column to datetime objects
def time_between_visits(df):
    results = []
    for patient_key in df["PatientDurableKey"].unique():
        patient_df = df.loc[df["PatientDurableKey"] == patient_key].sort_values(by = "Date", ascending = True)
        
        if len(patient_df) == 1:
            avg_wait = pd.to_timedelta(0, unit = 's')
            
        else: 
            time_btwn = []
            for i in range(0, len(patient_df) - 1):
                time_btwn.append(patient_df.iloc[i+1, 0] - patient_df.iloc[i, 0])
            avg_wait = np.mean(time_btwn)

        results.append({"Patient Key": patient_key, "Avg Wait Time": avg_wait})

    return pd.DataFrame(results)

# %%
depressives_waittime_df = time_between_visits(depressives_df)
depressives_waittime_df
# Out:
#        Patient Key     Avg Wait Time
# 0          5768589  60 days 00:00:00
# 1          6407984 289 days 00:00:00
# 2           432353 266 days 12:00:00
# 3           456168 182 days 00:00:00
# 4           122047   0 days 00:00:00
# ...            ...               ...
# 15557      8341048   0 days 00:00:00
# 15558       120672   0 days 00:00:00
# 15559     11101708   0 days 00:00:00
# 15560       466094   0 days 00:00:00
# 15561     11101611   0 days 00:00:00
#
# [15562 rows x 2 columns]

# %%
depressives_waittime_cleaned = depressives_waittime_df.loc[depressives_waittime_df["Avg Wait Time"] > pd.Timedelta(0)]

# %%
depressives_waittime_df.loc[depressives_waittime_df["Avg Wait Time"] > pd.Timedelta(0)].shape[0] / depressives_waittime_df.shape[0]
# Out:
# 0.34050893201387994

# %%
sns.histplot(depressives_waittime_cleaned["Avg Wait Time"].dt.days, bins = 30)
# Out:
# <Axes: xlabel='Avg Wait Time', ylabel='Count'>

# %%
depressives_waittime_cleaned["Avg Wait Time"].describe()
# Out:
# count                           5299
# mean     198 days 22:04:10.266616590
# std      227 days 11:11:24.110428652
# min                  0 days 12:00:00
# 25%                 41 days 00:00:00
# 50%                117 days 04:48:00
# 75%                278 days 18:00:00
# max               1433 days 00:00:00
# Name: Avg Wait Time, dtype: object

# %%
q1 = depressives_waittime_cleaned["Avg Wait Time"].quantile(0.25)
q3 = depressives_waittime_cleaned["Avg Wait Time"].quantile(0.75)
iqr = q3 - q1
outliers = depressives_waittime_cleaned[(depressives_waittime_cleaned["Avg Wait Time"] < (q1 - 1.5 * iqr)) | (depressives_waittime_cleaned["Avg Wait Time"] > (q3 + 1.5 * iqr))]
outliers
# Out:
#       Patient Key Avg Wait Time
# 32        5568769      713 days
# 35        8678533      805 days
# 36        6869432     1166 days
# 54        6562286      922 days
# 63        5726547      920 days
# ...           ...           ...
# 8548      9867930      708 days
# 8550      6195855      647 days
# 8857       979329      659 days
# 9402      6633947      665 days
# 9609      6799243      651 days
#
# [305 rows x 2 columns]

# %%
outliers.describe()
# Out:
#         Patient Key                Avg Wait Time
# count  3.050000e+02                          305
# mean   4.504207e+06  889 days 05:09:14.754098368
# std    3.065507e+06  194 days 07:34:23.271484582
# min    4.365300e+04            639 days 00:00:00
# 25%    6.538410e+05            731 days 00:00:00
# 50%    5.610651e+06            838 days 00:00:00
# 75%    6.792302e+06           1021 days 00:00:00
# max    1.012975e+07           1433 days 00:00:00

# %%
depressives_df
# Out:
#               Date     AdmissionInstant  AdmitYear  AdmitMonth  AdmitDay  \
# 232     2022-01-31                  NaN        NaN         NaN       NaN
# 272     2022-02-09                  NaN        NaN         NaN       NaN
# 329     2022-01-04                  NaN        NaN         NaN       NaN
# 2120    2022-01-19                  NaN        NaN         NaN       NaN
# 2481    2022-01-10                  NaN        NaN         NaN       NaN
# ...            ...                  ...        ...         ...       ...
# 6517653 2025-12-31  2025-12-31 12:20:00     2025.0        12.0      31.0
# 6517681 2025-12-31  2025-12-31 21:56:00     2025.0        12.0      31.0
# 6518140 2025-12-31  2025-12-31 00:26:00     2025.0        12.0      31.0
# 6518967 2025-12-31                  NaN        NaN         NaN       NaN
# 6519145 2025-12-31                  NaN        NaN         NaN       NaN
#
#          AdmitHour  AdmitMinute  \
# 232            NaN          NaN
# 272            NaN          NaN
# 329            NaN          NaN
# 2120           NaN          NaN
# 2481           NaN          NaN
# ...            ...          ...
# 6517653       12.0         20.0
# 6517681       21.0         56.0
# 6518140        0.0         26.0
# 6518967        NaN          NaN
# 6519145        NaN          NaN
#
#                                        AdmissionSource    AdmissionType  \
# 232                                    *Not Applicable  *Not Applicable
# 272                                    *Not Applicable  *Not Applicable
# 329                                    *Not Applicable  *Not Applicable
# 2120                                   *Not Applicable  *Not Applicable
# 2481                                   *Not Applicable  *Not Applicable
# ...                                                ...              ...
# 6517653  Transfer from a Hospital (Different Facility)           Urgent
# 6517681     Transfer from Another Health Care Facility           Urgent
# 6518140       Non-Health Care Facility Point of Origin        Emergency
# 6518967                                *Not Applicable  *Not Applicable
# 6519145                                *Not Applicable  *Not Applicable
#
#             DischargeInstant  ...  IsHospitalOutpatientVisit  \
# 232                      NaN  ...                          0
# 272                      NaN  ...                          0
# 329                      NaN  ...                          0
# 2120                     NaN  ...                          0
# 2481                     NaN  ...                          0
# ...                      ...  ...                        ...
# 6517653  2026-01-06 17:29:00  ...                          0
# 6517681  2026-01-03 11:53:00  ...                          0
# 6518140  2025-12-31 08:59:00  ...                          0
# 6518967                  NaN  ...                          0
# 6519145                  NaN  ...                          0
#
#          IsInpatientAdmission  IsObservation  IsOutpatientFaceToFaceVisit  \
# 232                         0              0                            1
# 272                         0              0                            1
# 329                         0              0                            1
# 2120                        0              0                            1
# 2481                        0              0                            1
# ...                       ...            ...                          ...
# 6517653                     1              0                            0
# 6517681                     1              0                            0
# 6518140                     0              0                            0
# 6518967                     0              0                            0
# 6519145                     0              0                            0
#
#          DiagnosisKey                                  GroupName  \
# 232          407627.0       Major depressive disorder, recurrent
# 272          605675.0  Major depressive disorder, single episode
# 329          698235.0  Major depressive disorder, single episode
# 2120         407627.0       Major depressive disorder, recurrent
# 2481         407639.0       Major depressive disorder, recurrent
# ...               ...                                        ...
# 6517653      906402.0       Major depressive disorder, recurrent
# 6517681      906402.0       Major depressive disorder, recurrent
# 6518140      854596.0  Major depressive disorder, single episode
# 6518967      407639.0       Major depressive disorder, recurrent
# 6519145      663628.0       Major depressive disorder, recurrent
#
#               GroupCode                                      DiagnosisName  \
# 232      ICD-10-CM: F33  Major depressive disorder, recurrent, mild( IC...
# 272      ICD-10-CM: F32        Depression, unspecified( ICD-10-CM: F32.A )
# 329      ICD-10-CM: F32  Other specified depressive episodes( ICD-10-CM...
# 2120     ICD-10-CM: F33  Major depressive disorder, recurrent, mild( IC...
# 2481     ICD-10-CM: F33  Major depressive disorder, recurrent, in parti...
# ...                 ...                                                ...
# 6517653  ICD-10-CM: F33  Major depressive disorder, recurrent severe wi...
# 6517681  ICD-10-CM: F33  Major depressive disorder, recurrent severe wi...
# 6518140  ICD-10-CM: F32  Major depressive disorder, single episode, uns...
# 6518967  ICD-10-CM: F33  Major depressive disorder, recurrent, in parti...
# 6519145  ICD-10-CM: F33  Major depressive disorder, recurrent, moderate...
#
#         DiagnosisValue Depressives
# 232              F33.0           1
# 272              F32.A           1
# 329             F32.89           1
# 2120             F33.0           1
# 2481            F33.41           1
# ...                ...         ...
# 6517653          F33.2           1
# 6517681          F33.2           1
# 6518140          F32.9           1
# 6518967         F33.41           1
# 6519145          F33.1           1
#
# [27490 rows x 37 columns]

# %%
county_mapping = pd.DataFrame({
    "CountyCode": [
        "001","003","005","007","009","011","013","015","017","019","021","023","025","027",
        "029","031","033","035","037","039","041","043","045","047","049","051","053","055",
        "057","059","061","063","065","067","069","071","073","075","077","079","081","083",
        "085","087","089","091","093","095","097","099","101","103","105","107","109","111",
        "113","115","117","119","121","123","125","127","129","131","133","135","137","139",
        "141","143","145","147","149","151","153","155","157","159","161","163","165","167",
        "169","171","173","175","177","179","181","183","185","187","189","191","193","195",
        "197","199","201","203","205","207","209"
    ],
    "CountyName": [
        "Allen","Anderson","Atchison","Barber","Barton","Bourbon","Brown","Butler","Chase",
        "Chautauqua","Cherokee","Cheyenne","Clark","Clay","Cloud","Coffey","Comanche","Cowley",
        "Crawford","Decatur","Dickinson","Doniphan","Douglas","Edwards","Elk","Ellis","Ellsworth",
        "Finney","Ford","Franklin","Geary","Gove","Graham","Grant","Gray","Greeley","Greenwood",
        "Hamilton","Harper","Harvey","Haskell","Hodgeman","Jackson","Jefferson","Jewell",
        "Johnson","Kearny","Kingman","Kiowa","Labette","Lane","Leavenworth","Lincoln","Linn",
        "Logan","Lyon","McPherson","Marion","Marshall","Meade","Miami","Mitchell","Montgomery",
        "Morris","Morton","Nemaha","Neosho","Ness","Norton","Osage","Osborne","Ottawa","Pawnee",
        "Phillips","Pottawatomie","Pratt","Rawlins","Reno","Republic","Rice","Riley","Rooks",
        "Rush","Russell","Saline","Scott","Sedgwick","Seward","Shawnee","Sheridan","Sherman",
        "Smith","Stafford","Stanton","Stevens","Sumner","Thomas","Trego","Wabaunsee","Wallace",
        "Washington","Wichita","Wilson","Woodson","Wyandotte"
    ]
})

# %%
patients = patients[
    patients["CensusBlockGroupFipsCode"].notna() &
    (patients["CensusBlockGroupFipsCode"] != "*Unspecified")
] # removing patients with null or unspecified census block group information - unsure whether or not to do this 

tiger_census_codes.head()

tiger_census_codes["GEOID"] = tiger_census_codes["GEOID"].astype(str)
tiger_census_codes["CountyFips"] = tiger_census_codes["GEOID"].str[:5]


tiger_geo = tiger_census_codes[[
    "GEOID",
    "CountyFips",
    "CENTLAT",
    "CENTLON",
    "PopulationValue"
]]


patients_geo = patients.merge(
    tiger_geo,
    left_on="CensusBlockGroupFipsCode",
    right_on="GEOID",
    how="left"
)

patients_geo["CountyCode"] = patients_geo["CountyFips"].str[-3:]

# %%
depressives_county_df = pd.merge(depressives_waittime_cleaned, patients_geo[["DurableKey", "CountyCode"]], left_on = 'Patient Key', right_on = 'DurableKey', how = 'inner')
depressives_county_df
# Out:
#       Patient Key     Avg Wait Time  DurableKey CountyCode
# 0         5768589  60 days 00:00:00   5768589.0        177
# 1         6407984 289 days 00:00:00   6407984.0        177
# 2          432353 266 days 12:00:00    432353.0        177
# 3          456168 182 days 00:00:00    456168.0        139
# 4         7125936 350 days 00:00:00   7125936.0        177
# ...           ...               ...         ...        ...
# 3776      8978413   7 days 00:00:00   8978413.0        149
# 3777      3634929   3 days 12:00:00   3634929.0        059
# 3778      6235071  22 days 00:00:00   6235071.0        177
# 3779       489869   8 days 12:00:00    489869.0        177
# 3780      9809058   2 days 15:00:00   9809058.0        161
#
# [3781 rows x 4 columns]

# %%
depressives_county_df = depressives_county_df[["Patient Key", "Avg Wait Time", "CountyCode"]]
depressives_county_df
# Out:
#       Patient Key     Avg Wait Time CountyCode
# 0         5768589  60 days 00:00:00        177
# 1         6407984 289 days 00:00:00        177
# 2          432353 266 days 12:00:00        177
# 3          456168 182 days 00:00:00        139
# 4         7125936 350 days 00:00:00        177
# ...           ...               ...        ...
# 3776      8978413   7 days 00:00:00        149
# 3777      3634929   3 days 12:00:00        059
# 3778      6235071  22 days 00:00:00        177
# 3779       489869   8 days 12:00:00        177
# 3780      9809058   2 days 15:00:00        161
#
# [3781 rows x 3 columns]

# %%
depressives_county_wt = (depressives_county_df.groupby("CountyCode").agg(AvgWaitTime = ("Avg Wait Time", "mean"), NumPatients=("Patient Key", "nunique"))
      .reset_index())
depressives_county_wt
# Out:
#    CountyCode                 AvgWaitTime  NumPatients
# 0         001           193 days 00:00:00            1
# 1         003           175 days 00:00:00            2
# 2         005 339 days 20:54:51.428571428           14
# 3         009           328 days 12:00:00            2
# 4         013           150 days 11:18:00            4
# 5         015           184 days 00:00:00            3
# 6         017           140 days 20:00:00            6
# 7         027           313 days 06:00:00            4
# 8         029            12 days 00:00:00            2
# 9         031 202 days 03:10:17.142857142           21
# 10        035           350 days 12:00:00            1
# 11        041 237 days 00:36:39.014778324           21
# 12        043           791 days 00:00:00            1
# 13        045 193 days 19:41:51.705069124           62
# 14        051            57 days 00:00:00            2
# 15        059           185 days 12:00:00           11
# 16        061 195 days 12:02:34.672395274          133
# 17        073           282 days 16:00:00            3
# 18        079           254 days 16:00:00            1
# 19        085 237 days 16:15:51.169773964           58
# 20        087 224 days 21:34:14.041636756          199
# 21        091 227 days 08:05:08.021390372           11
# 22        103 211 days 02:41:08.571428572           14
# 23        107           474 days 00:00:00            1
# 24        111 191 days 00:37:22.865988500          285
# 25        113            83 days 18:00:00            2
# 26        115            64 days 18:00:00            4
# 27        117           157 days 10:48:00            4
# 28        121           359 days 17:20:00            3
# 29        125           343 days 15:00:00            6
# 30        127           248 days 17:06:40            9
# 31        131            86 days 00:40:00            6
# 32        133            56 days 00:00:00            1
# 33        139 260 days 08:25:48.789390756          256
# 34        149 208 days 03:49:51.515151516           99
# 35        155           950 days 00:00:00            1
# 36        161 146 days 00:59:24.035964036          143
# 37        169           276 days 17:33:20            6
# 38        173           273 days 08:00:00            3
# 39        177 203 days 00:19:06.158548196         2322
# 40        181             5 days 00:00:00            1
# 41        197 248 days 18:07:15.918367348           42
# 42        201           164 days 00:00:00            2
# 43        205           230 days 17:36:00            3
# 44        207            30 days 00:00:00            1
# 45        209           351 days 06:00:00            2

# %%
depressives_county_wt_sorted = depressives_county_wt.sort_values("NumPatients", ascending=False)
depressives_county_wt_sorted
# Out:
#    CountyCode                 AvgWaitTime  NumPatients
# 39        177 203 days 00:19:06.158548196         2322
# 24        111 191 days 00:37:22.865988500          285
# 33        139 260 days 08:25:48.789390756          256
# 20        087 224 days 21:34:14.041636756          199
# 36        161 146 days 00:59:24.035964036          143
# 16        061 195 days 12:02:34.672395274          133
# 34        149 208 days 03:49:51.515151516           99
# 13        045 193 days 19:41:51.705069124           62
# 19        085 237 days 16:15:51.169773964           58
# 41        197 248 days 18:07:15.918367348           42
# 9         031 202 days 03:10:17.142857142           21
# 11        041 237 days 00:36:39.014778324           21
# 2         005 339 days 20:54:51.428571428           14
# 22        103 211 days 02:41:08.571428572           14
# 21        091 227 days 08:05:08.021390372           11
# 15        059           185 days 12:00:00           11
# 30        127           248 days 17:06:40            9
# 29        125           343 days 15:00:00            6
# 37        169           276 days 17:33:20            6
# 6         017           140 days 20:00:00            6
# 31        131            86 days 00:40:00            6
# 7         027           313 days 06:00:00            4
# 4         013           150 days 11:18:00            4
# 26        115            64 days 18:00:00            4
# 27        117           157 days 10:48:00            4
# 28        121           359 days 17:20:00            3
# 38        173           273 days 08:00:00            3
# 17        073           282 days 16:00:00            3
# 43        205           230 days 17:36:00            3
# 5         015           184 days 00:00:00            3
# 25        113            83 days 18:00:00            2
# 1         003           175 days 00:00:00            2
# 42        201           164 days 00:00:00            2
# 14        051            57 days 00:00:00            2
# 8         029            12 days 00:00:00            2
# 3         009           328 days 12:00:00            2
# 45        209           351 days 06:00:00            2
# 44        207            30 days 00:00:00            1
# 40        181             5 days 00:00:00            1
# 0         001           193 days 00:00:00            1
# 35        155           950 days 00:00:00            1
# 32        133            56 days 00:00:00            1
# 18        079           254 days 16:00:00            1
# 12        043           791 days 00:00:00            1
# 10        035           350 days 12:00:00            1
# 23        107           474 days 00:00:00            1

# %%
county_mapping.loc[county_mapping["CountyCode"] == "139"]
# Out:
#    CountyCode CountyName
# 69        139      Osage

# %%
county_mapping.loc[county_mapping["CountyCode"] == "111"]
# Out:
#    CountyCode CountyName
# 55        111       Lyon

# %%
county_mapping.loc[county_mapping["CountyCode"] == "161"]
# Out:
#    CountyCode CountyName
# 80        161      Riley

# %%
df = pd.merge(encounters, diagnosis, left_on='PrimaryDiagnosisKey', right_on='DiagnosisKey')
df['CANCER'] = df['GroupName'].str.contains('malignant', case=False, na=False).astype(int)
cancer_df = df.loc[df["CANCER"] == 1]
cancer_df["Date"] = pd.to_datetime(cancer_df["Date"], format='mixed')
# Out:
# /var/folders/5z/2qf3kgpn4s1268wng8ysvpl00000gq/T/ipykernel_1557/3029262007.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cancer_df["Date"] = pd.to_datetime(cancer_df["Date"], format='mixed')

# %%
cancer_waittime_df = time_between_visits(cancer_df)

# %%
cancer_waittime_df = cancer_waittime_df.loc[cancer_waittime_df["Avg Wait Time"] != pd.Timedelta(0, unit = 's')]

# %%
q1 = np.percentile(cancer_waittime_df["Avg Wait Time"], 25)
q3 = np.percentile(cancer_waittime_df["Avg Wait Time"], 75)

IQR = q3 - q1

upper_fence = q3 + 1.5 * IQR
lower_fence = q1 - 1.5 * IQR

outlier_bool = (cancer_waittime_df["Avg Wait Time"] > upper_fence) | (cancer_waittime_df["Avg Wait Time"] < lower_fence)
outliers_cancer = cancer_waittime_df.loc[outlier_bool]

cancer_wt_clean = cancer_waittime_df[~ cancer_waittime_df["Patient Key"].isin(outliers_cancer["Patient Key"])]

# %%
cancer_county_df = pd.merge(cancer_wt_clean, patients_geo[["DurableKey", "CountyCode"]], left_on = 'Patient Key', right_on = 'DurableKey', how = 'inner')
cancer_county_df = cancer_county_df[["Patient Key", "Avg Wait Time", "CountyCode"]]


cancer_county_wt = (cancer_county_df.groupby("CountyCode").agg(AvgWaitTime = ("Avg Wait Time", "mean"), NumPatients=("Patient Key", "nunique"))
      .reset_index())
cancer_county_wt.sort_values("NumPatients", ascending = False)
# Out:
#    CountyCode                 AvgWaitTime  NumPatients
# 50        177 286 days 17:26:53.797363300        23235
# 28        111 295 days 11:34:59.767930656         2482
# 39        139 277 days 19:09:22.103327224         1814
# 19        061 259 days 06:53:35.131700572         1562
# 44        161 240 days 10:07:59.012667896         1382
# 23        087 290 days 13:34:30.597014812         1309
# 42        149 234 days 07:21:47.577066484          760
# 22        085 274 days 13:38:43.059908968          759
# 52        197 291 days 04:24:50.008059936          517
# 14        045 261 days 06:53:44.367256444          378
# 9         031 272 days 19:18:24.965574088          220
# 12        041 265 days 20:53:32.656723268          203
# 36        131 200 days 07:42:17.561845236          166
# 35        127 251 days 18:34:56.778846152          128
# 4         013 233 days 13:40:02.075099784          100
# 6         017 290 days 21:08:38.412042500           88
# 25        091 329 days 03:12:05.208791208           80
# 20        073 279 days 20:17:11.468812876           71
# 7         027 189 days 18:16:54.770814362           67
# 31        117 219 days 16:02:53.171415488           63
# 2         005    263 days 22:26:52.884507           63
# 26        103 282 days 07:34:40.879120880           39
# 18        059 267 days 11:32:28.571428572           36
# 56        209 295 days 03:55:05.370843992           17
# 53        201           201 days 17:35:12           15
# 49        173 288 days 12:55:23.076923076           13
# 55        207 173 days 06:48:14.447657606           12
# 47        169           260 days 02:18:40           12
# 30        115           249 days 09:00:00           10
# 0         001 155 days 08:28:29.010989010            7
# 29        113 216 days 13:08:34.285714284            7
# 21        079 156 days 04:56:28.235294118            6
# 34        125           255 days 15:30:00            4
# 13        043            46 days 20:48:00            3
# 5         015           381 days 12:00:00            2
# 3         009           107 days 10:00:00            2
# 1         003           360 days 16:48:00            2
# 54        205           198 days 04:00:00            2
# 10        035           400 days 06:00:00            2
# 43        155           378 days 12:00:00            2
# 51        181            30 days 00:00:00            1
# 45        163           353 days 00:00:00            1
# 48        171           383 days 08:00:00            1
# 46        167            92 days 12:00:00            1
# 24        089            15 days 00:00:00            1
# 8         029           520 days 00:00:00            1
# 41        147           245 days 12:00:00            1
# 11        037            35 days 04:00:00            1
# 38        137           183 days 16:00:00            1
# 37        133           290 days 12:00:00            1
# 15        051           278 days 06:00:00            1
# 33        123           461 days 00:00:00            1
# 32        121           372 days 00:00:00            1
# 16        053           426 days 00:00:00            1
# 27        107           105 days 08:00:00            1
# 17        057           457 days 12:00:00            1
# 40        143            35 days 00:00:00            1

# %%
departments
# Out:
#        DepartmentKey            Address             City           County  \
# 0                 -3           *Deleted         *Deleted         *Deleted
# 1                 -2    *Not Applicable  *Not Applicable  *Not Applicable
# 2                 -1       *Unspecified     *Unspecified     *Unspecified
# 3                  1    1500 SW 10th ST           TOPEKA     *Unspecified
# 4                  2     1979 Milky Way           VERONA     *Unspecified
# ...              ...                ...              ...              ...
# 11592          12908  909 SW Mulvane St           TOPEKA          SHAWNEE
# 11593          12909    1414 SW 8th Ave           Topeka     *Unspecified
# 11594          12910                NaN              NaN     *Unspecified
# 11595          12911   1500 SW 10th Ave           Topeka          SHAWNEE
# 11596          12912      330 SW Oakley           TOPEKA          SHAWNEE
#
#                        DepartmentName      DepartmentSpecialty  \
# 0                            *Deleted                 *Deleted
# 1                     *Not Applicable          *Not Applicable
# 2                        *Unspecified             *Unspecified
# 3                        INITIAL DEPT             *Unspecified
# 4                         EHS UM DEPT             *Unspecified
# ...                               ...                      ...
# 11592    STORMONT VAIL ALLERGY CLINIC                  Allergy
# 11593          CC HEMATOLOGY ONCOLOGY  Hematology and Oncology
# 11594                    *Unspecified             *Unspecified
# 11595              SV PHARMACOTHERAPY                 Pharmacy
# 11596  ASTRA MENTAL HEALTH & RECOVERY          *Not Applicable
#
#         DepartmentType       PostalCode   CensusTract
# 0             *Deleted         *Deleted           NaN
# 1      *Not Applicable  *Not Applicable           NaN
# 2         *Unspecified     *Unspecified           NaN
# 3             *Unknown            66604  2.017700e+10
# 4             *Unknown            53593  5.502501e+10
# ...                ...              ...           ...
# 11592         *Unknown            66606  2.017700e+10
# 11593         *Unknown            66606  2.017700e+10
# 11594     *Unspecified              NaN           NaN
# 11595              HOD            66606  2.017700e+10
# 11596  *Not Applicable            66606  2.017700e+10
#
# [11597 rows x 9 columns]

# %%
encounters
# Out:
#              Date     AdmissionInstant  AdmitYear  AdmitMonth  AdmitDay  \
# 0        04/25/22  2022-04-25 20:33:00     2022.0         4.0      25.0
# 1        04/29/22  2022-04-29 18:18:00     2022.0         4.0      29.0
# 2        01/10/22  2022-01-10 05:52:00     2022.0         1.0      10.0
# 3        03/08/22  2022-03-08 09:08:00     2022.0         3.0       8.0
# 4        03/16/22  2022-03-16 14:19:00     2022.0         3.0      16.0
# ...           ...                  ...        ...         ...       ...
# 7675796  12/29/25                  NaN        NaN         NaN       NaN
# 7675797  12/12/25                  NaN        NaN         NaN       NaN
# 7675798  12/12/25                  NaN        NaN         NaN       NaN
# 7675799  08/20/25                  NaN        NaN         NaN       NaN
# 7675800  07/17/25                  NaN        NaN         NaN       NaN
#
#          AdmitHour  AdmitMinute                           AdmissionSource  \
# 0             20.0         33.0  Non-Health Care Facility Point of Origin
# 1             18.0         18.0                 Clinic/Physician Referral
# 2              5.0         52.0  Non-Health Care Facility Point of Origin
# 3              9.0          8.0  Non-Health Care Facility Point of Origin
# 4             14.0         19.0  Non-Health Care Facility Point of Origin
# ...            ...          ...                                       ...
# 7675796        NaN          NaN                           *Not Applicable
# 7675797        NaN          NaN                           *Not Applicable
# 7675798        NaN          NaN                           *Not Applicable
# 7675799        NaN          NaN                           *Not Applicable
# 7675800        NaN          NaN                           *Not Applicable
#
#            AdmissionType     DischargeInstant  ...  \
# 0               Elective  2022-04-25 21:35:00  ...
# 1               Elective  2022-04-29 18:20:00  ...
# 2               Elective  2022-01-12 11:43:00  ...
# 3               Elective  2022-03-10 13:45:00  ...
# 4               Elective  2022-03-16 16:00:00  ...
# ...                  ...                  ...  ...
# 7675796  *Not Applicable                  NaN  ...
# 7675797  *Not Applicable                  NaN  ...
# 7675798  *Not Applicable                  NaN  ...
# 7675799  *Not Applicable                  NaN  ...
# 7675800  *Not Applicable                  NaN  ...
#
#          AttendingProviderDurableKey  DischargeProviderDurableKey  \
# 0                               2982                         2982
# 1                               2979                         2979
# 2                               6223                         7015
# 3                               7973                         7973
# 4                               6223                         2982
# ...                              ...                          ...
# 7675796                        18326                           -1
# 7675797                           -1                           -1
# 7675798                        79382                           -1
# 7675799                         1868                           -1
# 7675800                         1868                           -1
#
#          DepartmentKey  PrimaryDiagnosisKey  IsEdVisit  IsHospitalAdmission  \
# 0                   27               910699          0                    1
# 1                   27                   -1          0                    1
# 2                   27               468738          0                    1
# 3                   27               468492          0                    1
# 4                   27               907210          0                    1
# ...                ...                  ...        ...                  ...
# 7675796             57               858635          0                    0
# 7675797          12707                   -1          0                    0
# 7675798             57               855970          0                    0
# 7675799          11805               853446          0                    0
# 7675800          11805               853446          0                    0
#
#          IsHospitalOutpatientVisit IsInpatientAdmission IsObservation  \
# 0                                0                    0             1
# 1                                0                    0             1
# 2                                0                    1             0
# 3                                0                    1             0
# 4                                0                    0             1
# ...                            ...                  ...           ...
# 7675796                          0                    0             0
# 7675797                          0                    0             0
# 7675798                          0                    0             0
# 7675799                          0                    0             0
# 7675800                          0                    0             0
#
#         IsOutpatientFaceToFaceVisit
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...
# 7675796                           1
# 7675797                           1
# 7675798                           1
# 7675799                           0
# 7675800                           0
#
# [7675801 rows x 31 columns]

# %%
patients
# Out:
#        CensusBlockGroupFipsCode  DurableKey           FirstRace MaritalStatus  \
# 0                  201770007002         5.0  White or Caucasian        Single
# 6                  201770030011        15.0  White or Caucasian        Single
# 7                  200850826001        17.0  White or Caucasian       Married
# 8                  201770016032        19.0  White or Caucasian        Single
# 19                 201314802002        45.0  White or Caucasian       Married
# ...                         ...         ...                 ...           ...
# 947673             200450006023  11135754.0                 NaN  *Unspecified
# 947674             201770031004  11135755.0                 NaN       Unknown
# 947676             201730095091  11135758.0                 NaN        Single
# 947678             201490001024  11135762.0                 NaN  *Unspecified
# 947684             201110003001  11135791.0  White or Caucasian       Married
#
#              MyChartStatus            OmbEthnicity  OmbRace  \
# 0                Activated  Not Hispanic or Latino    White
# 6                Activated  Not Hispanic or Latino    White
# 7                Activated     Asked but No Answer    White
# 8       Pending Activation                 Unknown    White
# 19               Activated  Not Hispanic or Latino    White
# ...                    ...                     ...      ...
# 947673        *Unspecified                 Unknown  Unknown
# 947674  Pending Activation                 Unknown  Unknown
# 947676         Inactivated                 Unknown  Unknown
# 947678           Activated                 Unknown  Unknown
# 947684           Activated  Not Hispanic or Latino    White
#
#        SexAssignedAtBirth SexualOrientation   SmokingStatus VitalStatus  \
# 0            *Unspecified      *Unspecified           Never       Alive
# 6            *Unspecified      *Unspecified       Every Day       Alive
# 7            *Unspecified      *Unspecified           Never       Alive
# 8            *Unspecified      *Unspecified  Never Assessed       Alive
# 19           *Unspecified      *Unspecified          Former       Alive
# ...                   ...               ...             ...         ...
# 947673       *Unspecified      *Unspecified        *Unknown       Alive
# 947674       *Unspecified      *Unspecified       Some Days       Alive
# 947676       *Unspecified      *Unspecified           Never       Alive
# 947678       *Unspecified      *Unspecified        *Unknown       Alive
# 947684       *Unspecified      *Unspecified           Never       Alive
#
#         PatientBirthYearBin
# 0                    1970.0
# 6                    1985.0
# 7                    1960.0
# 8                    2000.0
# 19                   1970.0
# ...                     ...
# 947673               1980.0
# 947674               1975.0
# 947676               2000.0
# 947678               2020.0
# 947684               1960.0
#
# [336514 rows x 12 columns]

# %%
df = pd.merge(df, patients[["DurableKey", "MyChartStatus"]], 
              left_on="PatientDurableKey", right_on="DurableKey", how="left")

# %%
depressives_with_mychart = pd.merge(
    depressives_waittime_df,
    patients[["DurableKey", "MyChartStatus"]],
    left_on="Patient Key",
    right_on="DurableKey",
    how="left"
)

# %%
df = pd.merge(encounters, diagnosis, 
              left_on="PrimaryDiagnosisKey", 
              right_on="DiagnosisKey")

df["FRACTURE"] = df["GroupName"].str.contains("fracture", case=False, na=False).astype(int)

fracture_df = df.loc[df["FRACTURE"] == 1].copy()
fracture_df["Date"] = pd.to_datetime(fracture_df["Date"], format="mixed")

# %%
def time_between_visits(df):
    df = df.sort_values(["PatientDurableKey", "Date"])
    
    df["next_visit"] = df.groupby("PatientDurableKey")["Date"].shift(-1)
    df["gap_days"] = (df["next_visit"] - df["Date"]).dt.days
    
    # remove invalid gaps
    df = df[df["gap_days"] > 0]
    
    result = df.groupby("PatientDurableKey")["gap_days"].mean().reset_index()
    result.columns = ["Patient Key", "Avg Wait Time"]
    
    return result

# %%
fracture_waittime_df = time_between_visits(fracture_df)

# %%
q1 = fracture_waittime_df["Avg Wait Time"].quantile(0.25)
q3 = fracture_waittime_df["Avg Wait Time"].quantile(0.75)

iqr = q3 - q1

fracture_clean = fracture_waittime_df[
    (fracture_waittime_df["Avg Wait Time"] >= q1 - 1.5 * iqr) &
    (fracture_waittime_df["Avg Wait Time"] <= q3 + 1.5 * iqr)
]

# %%
fracture_county_df = pd.merge(
    fracture_clean,
    patients_geo[["DurableKey", "CountyCode"]],
    left_on="Patient Key",
    right_on="DurableKey",
    how="inner"
)

fracture_county_df = fracture_county_df[
    ["Patient Key", "Avg Wait Time", "CountyCode"]
]

# %%
fracture_county_wt = (
    fracture_county_df
    .groupby("CountyCode")
    .agg(
        AvgWaitTime=("Avg Wait Time", "mean"),
        NumPatients=("Patient Key", "nunique")
    )
    .reset_index()
)

fracture_county_wt_sorted = fracture_county_wt.sort_values(
    "NumPatients", ascending=False
)

# %%
fracture_with_mychart = pd.merge(
    fracture_clean,
    patients[["DurableKey", "MyChartStatus"]],
    left_on="Patient Key",
    right_on="DurableKey",
    how="left"
)

# %%
def clean_mychart(x):
    if x == "Activated":
        return "Activated"
    else:
        return "Not Activated"

fracture_with_mychart["MyChartClean"] = fracture_with_mychart["MyChartStatus"].apply(clean_mychart)

# %%
fracture_with_mychart.groupby("MyChartClean")["Avg Wait Time"].mean()
# Out:
# MyChartClean
# Activated        55.355250
# Not Activated    43.333885
# Name: Avg Wait Time, dtype: float64

# %%
fracture_geo_mychart = pd.merge(
    fracture_with_mychart,
    patients_geo[["DurableKey", "CountyCode"]],
    left_on="Patient Key",
    right_on="DurableKey",
    how="left"
)

# %%
fracture_mychart_county = (
    fracture_geo_mychart
    .groupby(["CountyCode", "MyChartClean"])
    .agg(
        AvgWaitTime=("Avg Wait Time", "mean"),
        NumPatients=("Patient Key", "count")
    )
    .reset_index()
)

# %%
df["CANCER"] = df["GroupName"].str.contains(
    "malignant|cancer|carcinoma|neoplasm|tumor",
    case=False,
    na=False
).astype(int)

# %%
df = pd.merge(encounters, diagnosis,
              left_on="PrimaryDiagnosisKey",
              right_on="DiagnosisKey")

df = pd.merge(
    df,
    patients[["DurableKey", "MyChartStatus"]],
    left_on="PatientDurableKey",
    right_on="DurableKey",
    how="left"
)

df["CANCER"] = df["GroupName"].str.contains(
    "malignant|cancer|carcinoma|neoplasm|tumor",
    case=False,
    na=False
).astype(int)

cancer_df = df.loc[df["CANCER"] == 1].copy()
cancer_df["Date"] = pd.to_datetime(cancer_df["Date"], format="mixed")

# %%
cancer_waittime_df = time_between_visits(cancer_df)

# %%
q1 = cancer_waittime_df["Avg Wait Time"].quantile(0.25)
q3 = cancer_waittime_df["Avg Wait Time"].quantile(0.75)
iqr = q3 - q1

cancer_clean = cancer_waittime_df[
    (cancer_waittime_df["Avg Wait Time"] >= q1 - 1.5 * iqr) &
    (cancer_waittime_df["Avg Wait Time"] <= q3 + 1.5 * iqr)
]

# %%
cancer_with_mychart = pd.merge(
    cancer_clean,
    patients[["DurableKey", "MyChartStatus"]],
    left_on="Patient Key",
    right_on="DurableKey",
    how="left"
)

# %%
def clean_mychart(x):
    if x == "Activated":
        return "Activated"
    else:
        return "Not Activated"

cancer_with_mychart["MyChartClean"] = cancer_with_mychart["MyChartStatus"].apply(clean_mychart)

# %%
cancer_with_mychart.groupby("MyChartClean")["Avg Wait Time"].mean()
# Out:
# MyChartClean
# Activated        272.897265
# Not Activated    225.067224
# Name: Avg Wait Time, dtype: float64

# %%
cancer_with_mychart["LongGap"] = cancer_with_mychart["Avg Wait Time"] > 180

# %%
cancer_with_mychart.groupby("MyChartClean")["LongGap"].mean()
# Out:
# MyChartClean
# Activated        0.669247
# Not Activated    0.523830
# Name: LongGap, dtype: float64

# %%
cancer_with_mychart.groupby("MyChartClean")["Avg Wait Time"].median()
# Out:
# MyChartClean
# Activated        272.333333
# Not Activated    189.200000
# Name: Avg Wait Time, dtype: float64

# %%
visit_counts = cancer_df.groupby("PatientDurableKey").size()

cancer_with_mychart["NumVisits"] = cancer_with_mychart["Patient Key"].map(visit_counts)

# %%
cancer_with_mychart.groupby("MyChartClean")["NumVisits"].mean()
# Out:
# MyChartClean
# Activated        7.261043
# Not Activated    8.573301
# Name: NumVisits, dtype: float64

# %%
visit_counts = df.groupby("PatientDurableKey").size()
visit_counts
# Out:
# PatientDurableKey
# 5            9
# 9            6
# 17          33
# 19           1
# 33          11
#             ..
# 11101708     1
# 11101709     1
# 11101710     1
# 11101711     1
# 11135791     2
# Length: 348689, dtype: int64

# %%
journey_span = df.groupby("PatientDurableKey")["Date"].agg(
    lambda x: (x.max() - x.min()).days
)

# %%
df.columns
# Out:
# Index(['Date', 'AdmissionInstant', 'AdmitYear', 'AdmitMonth', 'AdmitDay',
#        'AdmitHour', 'AdmitMinute', 'AdmissionSource', 'AdmissionType',
#        'DischargeInstant', 'DischargeYear', 'DischargeMonth', 'DischargeDay',
#        'DischargeHour', 'DischargeMinute', 'EncounterKey', 'PatientDurableKey',
#        'Type', 'VisitType', 'VisitTypeDescription', 'ProviderDurableKey',
#        'AttendingProviderDurableKey', 'DischargeProviderDurableKey',
#        'DepartmentKey', 'PrimaryDiagnosisKey', 'IsEdVisit',
#        'IsHospitalAdmission', 'IsHospitalOutpatientVisit',
#        'IsInpatientAdmission', 'IsObservation', 'IsOutpatientFaceToFaceVisit',
#        'DiagnosisKey', 'GroupName', 'GroupCode', 'DiagnosisName',
#        'DiagnosisValue', 'DurableKey', 'MyChartStatus', 'CANCER'],
#       dtype='object')

# %%
df = df.copy()

df["Date"] = pd.to_datetime(df["Date"], format="mixed")

# drop rows without patient or date
df = df.dropna(subset=["PatientDurableKey", "Date"])

# %%
visit_counts = df.groupby("PatientDurableKey").size()

# %%
dept_counts = df.groupby("PatientDurableKey")["DepartmentKey"].nunique()

# %%
journey_duration = df.groupby("PatientDurableKey")["Date"].agg(
    lambda x: (x.max() - x.min()).days
)

# %%
inpatient_usage = df.groupby("PatientDurableKey")["IsInpatientAdmission"].sum()

# %%
ed_usage = df.groupby("PatientDurableKey")["IsEdVisit"].sum()

# %%
journey_df = pd.DataFrame({
    "PatientKey": visit_counts.index,
    "NumVisits": visit_counts.values,
    "NumDepartments": dept_counts.values,
    "Duration": journey_duration.values,
    "EDVisits": ed_usage.values,
    "InpatientVisits": inpatient_usage.values
})

# %%
journey_df
# Out:
#         PatientKey  NumVisits  NumDepartments  Duration  EDVisits  \
# 0                5          9               5       127         0
# 1                9          6               4       194         0
# 2               17         33               5      1232         0
# 3               19          1               1         0         0
# 4               33         11               5      1285         0
# ...            ...        ...             ...       ...       ...
# 348684    11101708          1               1         0         0
# 348685    11101709          1               1         0         1
# 348686    11101710          1               1         0         0
# 348687    11101711          1               1         0         1
# 348688    11135791          2               2         0         0
#
#         InpatientVisits  LongDuration  HighUtilization  Fragmented  \
# 0                     0         False             True        True
# 1                     0          True             True        True
# 2                     0          True             True        True
# 3                     0         False            False       False
# 4                     0          True             True        True
# ...                 ...           ...              ...         ...
# 348684                1         False            False       False
# 348685                0         False            False       False
# 348686                0         False            False       False
# 348687                0         False            False       False
# 348688                0         False            False       False
#
#         ComplexityScore  Cluster
# 0                  31.4        1
# 1                  43.0        1
# 2                 264.4        0
# 3                   0.8        1
# 4                 264.0        0
# ...                 ...      ...
# 348684              0.8        1
# 348685              0.8        1
# 348686              0.8        1
# 348687              0.8        1
# 348688              1.6        1
#
# [348689 rows x 11 columns]

# %%
journey_df["LongDuration"] = journey_df["Duration"] > 180
journey_df["HighUtilization"] = journey_df["NumVisits"] > 5
journey_df["Fragmented"] = journey_df["NumDepartments"] > 3

# %%
journey_df[["LongDuration", "HighUtilization", "Fragmented"]].mean()
# Out:
# LongDuration       0.680062
# HighUtilization    0.563689
# Fragmented         0.467548
# dtype: float64

# %%
journey_df["ComplexityScore"] = (
    journey_df["NumVisits"] * 0.5 +
    journey_df["NumDepartments"] * 0.3 +
    journey_df["Duration"] * 0.2
)

# %%
journey_geo = pd.merge(
    journey_df,
    patients_geo[["DurableKey", "CountyCode"]],
    left_on="PatientKey",
    right_on="DurableKey",
    how="left"
)

# %%
county_complexity = (
    journey_geo
    .groupby("CountyCode")
    .agg(
        AvgComplexity=("ComplexityScore", "mean"),
        NumPatients=("PatientKey", "count")
    )
    .reset_index()
)

# %%
from sklearn.cluster import KMeans

features = journey_df[["NumVisits", "NumDepartments", "Duration"]]

kmeans = KMeans(n_clusters=4, random_state=0)
journey_df["Cluster"] = kmeans.fit_predict(features)

# %%
cluster_df = journey_df.groupby("Cluster").mean()
cluster_df
# Out:
#            PatientKey  NumVisits  NumDepartments     Duration  EDVisits  \
# Cluster
# 0        4.458425e+06  41.774724       10.016416  1310.363221  1.146925
# 1        5.767730e+06   2.753384        1.735452    41.537971  0.313682
# 2        4.900349e+06  10.376600        3.955465   468.784970  0.695424
# 3        4.248867e+06  17.397774        5.441278   914.637716  0.942378
#
#          InpatientVisits  LongDuration  HighUtilization  Fragmented  \
# Cluster
# 0               0.338440      1.000000         0.956525    0.841670
# 1               0.144254      0.084907         0.102444    0.084005
# 2               0.241130      1.000000         0.558289    0.420093
# 3               0.269078      1.000000         0.784762    0.608657
#
#          ComplexityScore
# Cluster
# 0             285.964931
# 1              10.204922
# 2             100.131934
# 3             193.258814

# %%
df_cancer = df[df["CANCER"] == 1]

# %%
import matplotlib.pyplot as plt

cluster_summary = journey_df.groupby("Cluster").mean()

cluster_summary[["NumVisits", "NumDepartments", "Duration"]].plot(kind="bar")
plt.title("Patient Journey Profiles by Cluster")
plt.ylabel("Average Value")
plt.xticks(rotation=0)
plt.show()

# %%
journey_df["Cluster"].value_counts(normalize=True).sort_index().plot(kind="bar")

plt.title("Distribution of Patient Types")
plt.ylabel("Proportion of Patients")
plt.xlabel("Cluster")
plt.show()

# %%
plt.scatter(journey_df["NumDepartments"], journey_df["Duration"], alpha=0.3)
plt.xlabel("Number of Departments")
plt.ylabel("Duration (days)")
plt.title("Fragmentation vs Care Duration")
plt.show()

# %%
import matplotlib.pyplot as plt

for c in journey_df["Cluster"].unique():
    subset = journey_df[journey_df["Cluster"] == c]
    plt.scatter(subset["NumVisits"], subset["Duration"], label=f"Cluster {c}", alpha=0.4)

plt.xlabel("Number of Visits")
plt.ylabel("Duration (days)")
plt.title("Patient Journey Clusters")
plt.legend()
plt.show()

# %%
county_complexity.sort_values("AvgComplexity", ascending=False)
# Out:
#    CountyCode  AvgComplexity  NumPatients
# 54        139     213.273204         8311
# 72        177     204.730044       107284
# 34        087     196.720328         6838
# 79        197     188.553968         2911
# 42        111     183.033664        12895
# ..        ...            ...          ...
# 20        049       1.750000            2
# 60        151       0.800000            4
# 3         007       0.800000            1
# 31        077       0.800000            5
# 73        179       0.800000            2
#
# [84 rows x 3 columns]

# %%
county_complexity
# Out:
#    CountyCode  AvgComplexity  NumPatients
# 0         001      72.494382           89
# 1         003      47.700000           95
# 2         005     101.816062          909
# 3         007       0.800000            1
# 4         009      79.001613           62
# ..        ...            ...          ...
# 79        197     188.553968         2911
# 80        201      81.536044          455
# 81        205     106.990909           55
# 82        207      87.345600          125
# 83        209     110.312308          130
#
# [84 rows x 3 columns]

# %%
county_complexity_filtered = county_complexity.loc[(county_complexity["CountyCode"] != "177") & (county_complexity["NumPatients"] > 400)]

# %%
county_complexity_filtered
# Out:
#    CountyCode  AvgComplexity  NumPatients
# 2         005     101.816062          909
# 6         013     116.562191         1698
# 8         017     151.018164          501
# 10        027     102.591554         1184
# 12        031     133.977108         1708
# 16        041     117.255121         1689
# 18        045     120.293632         4067
# 25        059     109.371245          466
# 26        061     122.876109        10573
# 33        085     169.641339         5692
# 34        087     196.720328         6838
# 36        091     110.679412          714
# 38        103      97.025502          647
# 42        111     183.033664        12895
# 45        117     100.704379         1119
# 49        127     130.624540         1088
# 50        131     116.461576         3084
# 54        139     213.273204         8311
# 59        149     141.316398         7446
# 65        161     109.434619        11849
# 79        197     188.553968         2911
# 80        201      81.536044          455

# %%
# visualize avgcomplexity and numpatients and get rid of county 177

plt.figure(figsize=(12, 6))
plt.scatter(county_complexity_filtered["AvgComplexity"], county_complexity_filtered["NumPatients"], alpha=0.6)
plt.title("Average Complexity vs Number of Patients")
plt.xlabel("Average Complexity")
plt.ylabel("Number of Patients")
plt.grid()
plt.show()
